# %%
import pickle as pkl
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
import seaborn as sns
from sklearn.model_selection import train_test_split

# %%
# Импорт таблицы
data = pd.read_csv('b_data.csv')

# %%
df = data

price_dynamics['jun_jul'] = round(((data['price_jul'] - data['price_may']) / data['price_may']) * 100, 2)
price_dynamics['jul_aug'] = round((((data['price_aug'] - data['price_jul']) / data['price_jul']) * 100)/2, 2)

price_dynamics = price_dynamics.rename(columns={'jun_jul': 'jun_jul, %', 'jul_aug': 'jul_aug, %'})

display(price_dynamics)
# Out:
#         location  feb_apr, %  apr_may, %  jun_jul, %  jul_aug, %
# 0       Пересвет       -2.20       -1.11       -1.07       -1.26
# 1          Верея       -1.96        1.11       -1.15       -1.16
# 2   Черноголовка       -2.45        0.72       -0.96       -1.17
# 3         Дрезна       -2.34        0.98       -1.35       -0.95
# 4    Дзержинский       -2.40       -0.80       -1.07       -1.01
# ..           ...         ...         ...         ...         ...
# 66        Видное       -2.35        0.81        1.01       -1.94
# 67   Воскресенск       -2.34        0.84       -1.03       -1.17
# 68       Зарайск       -2.55        0.61       -3.39        0.00
# 69     Жуковский       -2.29        0.88       -1.48       -1.13
# 70    Звенигород       -2.32        0.83       -1.41       -0.95
#
# [71 rows x 5 columns]

# %%
# Создание новых колонок price_4 и price_2
price_dynamics['price_4'] = price_dynamics['feb_apr, %'] + price_dynamics['apr_may, %']
price_dynamics['price_2'] = price_dynamics['jun_jul, %'] + price_dynamics['jul_aug, %']

display(price_dynamics)
# Out:
#         location  feb_apr, %  apr_may, %  jun_jul, %  jul_aug, %  price_4  \
# 0       Пересвет       -2.20       -1.11       -1.07       -1.26    -3.31
# 1          Верея       -1.96        1.11       -1.15       -1.16    -0.85
# 2   Черноголовка       -2.45        0.72       -0.96       -1.17    -1.73
# 3         Дрезна       -2.34        0.98       -1.35       -0.95    -1.36
# 4    Дзержинский       -2.40       -0.80       -1.07       -1.01    -3.20
# ..           ...         ...         ...         ...         ...      ...
# 66        Видное       -2.35        0.81        1.01       -1.94    -1.54
# 67   Воскресенск       -2.34        0.84       -1.03       -1.17    -1.50
# 68       Зарайск       -2.55        0.61       -3.39        0.00    -1.94
# 69     Жуковский       -2.29        0.88       -1.48       -1.13    -1.41
# 70    Звенигород       -2.32        0.83       -1.41       -0.95    -1.49
#
#     price_2
# 0     -2.33
# 1     -2.31
# 2     -2.13
# 3     -2.30
# ...

# %%
price_dynamics.to_csv('price_dynamics.csv', index=False)
